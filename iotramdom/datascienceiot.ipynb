# %%
import pandas as pd
d1=pd.read_csv("patients.csv")
# d1
# d1.info()
d1.describe() # For math summary
# d1.head(5)
# d1.tail(15) # for last 15
# d1.min() # for min value
# d1.max() # for max value
# d1.isnull() # for null value
# d1.isnull().sum()
# d1.iloc[14:25] # to find the data from 15 to 25
# Out:
#                age  satisfaction
# count  1000.000000   1000.000000
# mean     45.337000     79.597000
# std      25.999912     11.550325
# min       0.000000     60.000000
# 25%      23.000000     70.000000
# 50%      46.000000     80.000000
# 75%      68.000000     89.250000
# max      89.000000     99.000000
